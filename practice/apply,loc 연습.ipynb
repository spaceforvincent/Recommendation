# %% [markdown]
# ### 정규표현식을 사용하지 않고 개봉연도 수정하기

# %%
import pandas as pd

# %%
movies = pd.read_csv('/content/drive/MyDrive/추천시스템 입문/data/movies.csv').set_index('movieId')
movies.sample()
# Out:
#                                                      title         genres
# movieId
# 5640     Godzilla, King of the Monsters! (Kaijû-ô Gojir...  Horror|Sci-Fi

# %%
sample_movie = movies['title'][1]
sample_movie
# Out:
# 'Jumanji (1995)'

# %%
sample_movie[-5:-1]
# Out:
# '1995'

# %%
def get_year(x) :
  return x[-5:-1]

# %%
get_year(sample_movie)
# Out:
# '1995'

# %%
years = []
for title in movies['title']:
  years.append(get_year(title))
years[:5]
# Out:
# ['1995', '1995', '1995', '1995', '1995']

# %%
years = list(set(years))

# %% [markdown]
# ### lambda 사용

# %%
movies['year'] = movies['title'].apply(lambda x: x[-5:-1]) #apply가 for문의 역할을 함
movies['year'].unique()
# Out:
# array(['1995', '1994', '1996', '1976', '1992', '1967', '1993', '1964',
#        '1977', '1965', '1982', '1990', '1991', '1989', '1937', '1940',
#        '1969', '1981', '1973', '1970', '1955', '1959', '1968', '1988',
#        '1997', '1972', '1943', '1952', '1951', '1957', '1961', '1958',
#        '1954', '1934', '1944', '1960', '1963', '1942', '1941', '1953',
#        '1939', '1950', '1946', '1945', '1938', '1947', '1935', '1936',
#        '1956', '1949', '1932', '1975', '1974', '1971', '1979', '1987',
#        '1986', '1980', '1978', '1985', '1966', '1962', '1983', '1984',
#        '1948', '1933', '1931', '1922', '1998', '1929', '1930', '1927',
#        '1928', '1999', '2000', '1926', '1919', '1921', '1925', '1923',
#        '2001', '2002', '2003', '1920', '1915', '1924', '2004', '1916',
#        '1917', '999)', '2005', '2006', '1902', 'lon ', '1903', '2007',
#        '2008', '008)', '007)', '2009', '2010', '2011', '2012', '011)',
# ...

# %% [markdown]
# ### loc 사용하기

# %%
movies[movies['year']=='012)']
# Out:
#       movieId                         title                    genres  year
# 8148   102084  Justice League: Doom (2012)   Action|Animation|Fantasy  012)

# %%
#pandas location
#movies.loc[index, column]
movies.loc[102084, 'title'].strip()
# Out:
# 'Justice League: Doom (2012)'

# %%
movies['title'] = movies['title'].apply(lambda x:x.strip()) $

# %%
movies['year'] = movies['title'].apply(lambda x: x[-5:-1])
movies['year'].unique()
# Out:
# array(['1995', '1994', '1996', '1976', '1992', '1967', '1993', '1964',
#        '1977', '1965', '1982', '1990', '1991', '1989', '1937', '1940',
#        '1969', '1981', '1973', '1970', '1955', '1959', '1968', '1988',
#        '1997', '1972', '1943', '1952', '1951', '1957', '1961', '1958',
#        '1954', '1934', '1944', '1960', '1963', '1942', '1941', '1953',
#        '1939', '1950', '1946', '1945', '1938', '1947', '1935', '1936',
#        '1956', '1949', '1932', '1975', '1974', '1971', '1979', '1987',
#        '1986', '1980', '1978', '1985', '1966', '1962', '1983', '1984',
#        '1948', '1933', '1931', '1922', '1998', '1929', '1930', '1927',
#        '1928', '1999', '2000', '1926', '1919', '1921', '1925', '1923',
#        '2001', '2002', '2003', '1920', '1915', '1924', '2004', '1916',
#        '1917', '2005', '2006', '1902', 'lon ', '1903', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
# ...

# %%
errors = ['lon ', 'r On', ' Roa', 'atso', 'imal', 'erso',
       'ligh', 'he O', 'osmo', ' Bab', 'ron ', 'irro']

# %%
movies[movies['year'].isin(errors)]
# Out:
#                                                      title  \
# movieId
# 40697                                            Babylon 5
# 140956                                    Ready Player One
# 143410                                          Hyena Road
# 147250   The Adventures of Sherlock Holmes and Doctor W...
# 149334                                   Nocturnal Animals
# 156605                                            Paterson
# 162414                                           Moonlight
# 167570                                              The OA
# 171495                                              Cosmos
# 171631                             Maria Bamford: Old Baby
# 171891                                   Generation Iron 2
# 176601                                        Black Mirror
#
#                          genres  year
# movieId
# 40697                    Sci-Fi  lon
# 140956   Action|Sci-Fi|Thriller  r On
# 143410       (no genres listed)   Roa
# ...

# %%
#pandas location
#movies.loc[필터링정보(boolean), column]
movies.loc[movies['year'].isin(errors),'year'] = '2050'

# %%
movies['year'].unique()
# Out:
# array(['1995', '1994', '1996', '1976', '1992', '1967', '1993', '1964',
#        '1977', '1965', '1982', '1990', '1991', '1989', '1937', '1940',
#        '1969', '1981', '1973', '1970', '1955', '1959', '1968', '1988',
#        '1997', '1972', '1943', '1952', '1951', '1957', '1961', '1958',
#        '1954', '1934', '1944', '1960', '1963', '1942', '1941', '1953',
#        '1939', '1950', '1946', '1945', '1938', '1947', '1935', '1936',
#        '1956', '1949', '1932', '1975', '1974', '1971', '1979', '1987',
#        '1986', '1980', '1978', '1985', '1966', '1962', '1983', '1984',
#        '1948', '1933', '1931', '1922', '1998', '1929', '1930', '1927',
#        '1928', '1999', '2000', '1926', '1919', '1921', '1925', '1923',
#        '2001', '2002', '2003', '1920', '1915', '1924', '2004', '1916',
#        '1917', '2005', '2006', '1902', '2050', '1903', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '1908'], dtype=object)
